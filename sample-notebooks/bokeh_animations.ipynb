# %% [markdown]
# <h1 style="color:#D30982;">Bokeh widgets for math and quantum concepts</h1>
#
# <h5 style="color:red;">credits: Erik Weiss</h5>
#
# Erik made a lot of the following widgets. I collected them and put them in a single notebook. Some of the code was out of date, so, I updated all the functions that were incompatible with the latest versions of ipywidgets.

# %% [markdown]
# # Math widgets

# %% [markdown]
# ## Build a vector

# %%
# %run ../src/animation-functions/bokeh-build_vector.py
# Out:
#   <div id="ce402e76-d9b2-4bb1-a6ac-683f048bd7fc" data-root-id="p16526" style="display: contents;"></div>

# %% [markdown]
# ## Scaling a vector

# %%
# %run ../src/animation-functions/scale_vector.py
# Out:
# ...
# Output(layout=Layout(height='375px'))

# %% [markdown]
# ## Interference Demo

# %%
# %run ../src/animation-functions/bokeh-interference.py
# Out:
#   <div id="b922de00-e5ca-4dee-86d7-1ba3224d1b6c" data-root-id="p16629" style="display: contents;"></div>

# %%
# %run ../src/animation-functions/bokeh-m1_interference_singleplot_slider.py
# Out:
#   <div id="dc861653-42c0-457f-a007-5855bd6662b1" data-root-id="p16695" style="display: contents;"></div>

# %%
# %run ../src/animation-functions/bokeh-interference_phase.py
# Out:
#   <div id="dd2c3e9e-de1e-4917-bd48-0e62a4586d16" data-root-id="p16804" style="display: contents;"></div>

# %% [markdown]
# ## Building a 3D vector from its components.

# %%
# %run ../src/animation-functions/bokeh-build_vector.py
# Out:
#   <div id="bc24bd82-27c7-4e81-9a7b-e881add4e689" data-root-id="p17449" style="display: contents;"></div>

# %% [markdown]
# ## Division operation of two complex vectors

# %%
# %run ../src/animation-functions/bokeh-complex_unit_circle.py
# Out:
#   <div id="a0905990-69d3-4674-8fd5-6475f8cedcca" data-root-id="p17549" style="display: contents;"></div>

# %% [markdown]
# ## Loaded die simulations

# %%
# %run ../src/animation-functions/bokeh-loaded_die.py
# Out:
#   <div id="bcf94b38-f743-41fc-8df6-f2dde1f9e743" data-root-id="p17641" style="display: contents;"></div>

# %% [markdown]
# ## Widget for demonstrating change of basis for a 2D vector space

# %%
# %run ../src/animation-functions/bokeh-vector_basis_extended.py
# Out:
#   <div id="f904dfe5-5e41-4bdb-8f9d-e3a255807d11" data-root-id="p17768" style="display: contents;"></div>

# %% [markdown]
# ## Widget exercise for modifying a vector components to reach a point in vector space.

# %%
# %run ../src/animation-functions/bokeh-vector_basis.py
# Out:
#   <div id="daae1e14-e308-43d3-b399-5e7c36bcbb5b" data-root-id="p21064" style="display: contents;"></div>

# %% [markdown]
# ## Widget for a wave

# %%
# %run ../src/animation-functions/bokeh-wave.py
# Out:
#   <div id="d3b27de7-e854-4ce3-b371-20f66d918f18" data-root-id="p21113" style="display: contents;"></div>

# %% [markdown]
# # Quantum Widgets

# %% [markdown]
# ## Particle in a box

# %%
# %run ../src/animation-functions/bokeh-particle_box.py
# Out:
#   <div id="a2c122c6-e4a2-42f7-ba28-a51d64cae8b5" data-root-id="p21173" style="display: contents;"></div>

# %% [markdown]
# ## Double-slit experiment probability distribution

# %%
# %run ../src/animation-functions/bokeh-double_slit.py
# Out:
#   <div id="d8d3bbc9-9cf6-4c7f-9cc0-6c84d4eb4aa6" data-root-id="p21447" style="display: contents;"></div>

# %% [markdown]
# # Fireworks experiment
# reference: https://qbook.qbraid.com look for 'A Puzzle to get started.'

# %%
# %run ../src/animation-functions/bokeh-firework.py
# Out:
#   <div id="b3c25086-e967-446e-af75-b53dbcc7e7ce" data-root-id="p21700" style="display: contents;"></div>
